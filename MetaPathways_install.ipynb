# %% [markdown]
# <a href="https://colab.research.google.com/github/taltman/MetaPathwaysColab/blob/main/MetaPathways_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a notebook for assessing how easy it would be to run MetaPathways from within Google Colab. It is also helpful for debugging installation instructions.

# %% [markdown]
# # Configuring Google Colab for use with Conda

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# !mamba install -c hallamlab -c bioconda -c conda-forge metapathways
# Out:
# Looking for: ['metapathways']
#
# [+] 0.0s
# hallamlab/linux-64    ⣾
# hallamlab/noarch      ⣾
# bioconda/linux-64     ⣾
# bioconda/noarch       ⣾
# conda-forge/linux-64  ⣾  bioconda/noarch                                               No change
# bioconda/linux-64                                             No change
# [+] 0.1s
# hallamlab/linux-64    ⣾
# hallamlab/noarch      ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# hallamlab/linux-64    ⣾
# hallamlab/noarch      ⣾
# conda-forge/linux-64   4%
# conda-forge/noarch     1%hallamlab/noarch                                              No change
# [+] 0.3s
# hallamlab/linux-64    ⣾
# conda-forge/linux-64  13%
# conda-forge/noarch     9%hallamlab/linux-64                                            No change
# [+] 0.4s
# conda-forge/linux-64  14%
# conda-forge/noarch    28%[+] 0.5s
# conda-forge/linux-64  22%
# conda-forge/noarch    38%[+] 0.6s
# conda-forge/linux-64  27%
# conda-forge/noarch    48%[+] 0.7s
# conda-forge/linux-64  31%
# conda-forge/noarch    59%[+] 0.8s
# conda-forge/linux-64  31%
# conda-forge/noarch    69%[+] 0.9s
# conda-forge/linux-64  35%
# conda-forge/noarch    79%[+] 1.0s
# conda-forge/linux-64  40%
# conda-forge/noarch    79%[+] 1.1s
# conda-forge/linux-64  40%
# conda-forge/noarch    90%[+] 1.2s
# conda-forge/linux-64  44%
# conda-forge/noarch   100%conda-forge/noarch
# [+] 1.3s
# conda-forge/linux-64  49%[+] 1.4s
# conda-forge/linux-64  53%[+] 1.5s
# conda-forge/linux-64  53%[+] 1.6s
# conda-forge/linux-64  53%[+] 1.7s
# conda-forge/linux-64  53%[+] 1.8s
# conda-forge/linux-64  53%[+] 1.9s
# conda-forge/linux-64  53%[+] 2.0s
# conda-forge/linux-64  59%[+] 2.1s
# conda-forge/linux-64  63%[+] 2.2s
# conda-forge/linux-64  72%[+] 2.3s
# conda-forge/linux-64  72%[+] 2.4s
# conda-forge/linux-64  84%[+] 2.5s
# conda-forge/linux-64  93%[+] 2.6s
# conda-forge/linux-64 100%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - metapathways
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                          Version  Build                Channel           Size
# ─────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   + pcre                              8.45  h9c3ff4c_0           conda-forge     Cached
#   + zlib                            1.2.13  hd590300_5           conda-forge       93kB
#   + cython                          3.0.10  py310hc6cd4ac_0      conda-forge     Cached
#   + libgfortran5                    13.2.0  h3d2ce59_13          conda-forge        1MB
#   + frozenlist                       1.4.1  py310h2372a71_0      conda-forge     Cached
#   + multidict                        6.0.5  py310h2372a71_0      conda-forge     Cached
#   + libcrc32c                        1.1.2  h9c3ff4c_0           conda-forge     Cached
#   + libdeflate                        1.20  hd590300_0           conda-forge     Cached
#   + bcrypt                           4.2.0  py310h42e942d_0      conda-forge     Cached
#   + libabseil                   20240116.2  cxx17_he02047a_1     conda-forge     Cached
#   + libxcrypt                       4.4.36  hd590300_1           conda-forge     Cached
#   + datrie                           0.8.2  py310h2372a71_7      conda-forge     Cached
#   + psutil                           6.0.0  py310hc51659f_0      conda-forge     Cached
#   + wrapt                           1.16.0  py310h2372a71_0      conda-forge     Cached
#   + rpds-py                         0.19.1  py310h42e942d_0      conda-forge     Cached
#   + markupsafe                       2.1.5  py310h2372a71_0      conda-forge     Cached
#   + yaml                             0.2.5  h7f98852_2           conda-forge     Cached
#   + gettext-tools                   0.22.5  h59595ed_2           conda-forge     Cached
#   + libasprintf                     0.22.5  h661eb56_2           conda-forge     Cached
#   + libgettextpo                    0.22.5  h59595ed_2           conda-forge     Cached
#   + libsodium                       1.0.18  h36c2ea0_1           conda-forge     Cached
#   + libunistring                    0.9.10  h7f98852_0           conda-forge     Cached
#   + libgfortran-ng                  13.2.0  h69a702a_13          conda-forge       48kB
#   + yarl                             1.9.4  py310h2372a71_0      conda-forge     Cached
#   + google-crc32c                    1.1.2  py310hc5c09a0_5      conda-forge     Cached
#   + libprotobuf                     4.25.3  h08a7969_0           conda-forge     Cached
#   + perl                            5.32.1  7_hd590300_perl5     conda-forge     Cached
#   + pyyaml                           6.0.1  py310h2372a71_1      conda-forge     Cached
#   + libasprintf-devel               0.22.5  h661eb56_2           conda-forge     Cached
#   + libgettextpo-devel              0.22.5  h59595ed_2           conda-forge     Cached
#   + cryptography                    43.0.0  py310h4909e49_0      conda-forge     Cached
#   + curl                             8.5.0  hca28451_0           conda-forge       95kB
#   + libopenblas                     0.3.27  pthreads_hac2b453_1  conda-forge     Cached
#   + protobuf                        4.25.3  py310ha8c1f0e_0      conda-forge     Cached
#   + gettext                         0.22.5  h59595ed_2           conda-forge     Cached
#   + openblas                        0.3.27  pthreads_h9eca1d5_1  conda-forge     Cached
#   + libblas                          3.9.0  23_linux64_openblas  conda-forge     Cached
#   + libidn2                          2.3.7  hd590300_0           conda-forge     Cached
#   + libcblas                         3.9.0  23_linux64_openblas  conda-forge     Cached
#   + liblapack                        3.9.0  23_linux64_openblas  conda-forge     Cached
#   + wget                            1.21.4  hda4d442_0           conda-forge     Cached
#   + gsl                                2.7  he838d99_0           conda-forge     Cached
#   + liblapacke                       3.9.0  23_linux64_openblas  conda-forge     Cached
#   + numpy                            2.0.1  py310hf9f9071_0      conda-forge     Cached
#   + coin-or-utils                  2.11.11  hee58242_0           conda-forge     Cached
#   + scipy                           1.14.0  py310h93e2701_1      conda-forge     Cached
#   + coin-or-osi                   0.108.10  haf5fa05_0           conda-forge     Cached
#   + coin-or-clp                     1.17.8  h1ee7a9c_0           conda-forge     Cached
#   + coin-or-cgl                     0.60.7  h516709c_0           conda-forge     Cached
#   + coin-or-cbc                    2.10.11  h56f689f_0           conda-forge     Cached
#   + filechunkio                        1.8  py_2                 conda-forge     Cached
#   + html2text                    2024.2.26  pyhd8ed1ab_1         conda-forge     Cached
#   + sexpdata                         1.0.2  pyhd8ed1ab_0         conda-forge     Cached
#   + python-tzdata                   2024.1  pyhd8ed1ab_0         conda-forge     Cached
#   + pytz                            2024.1  pyhd8ed1ab_0         conda-forge     Cached
#   + attrs                           23.2.0  pyh71513ae_0         conda-forge     Cached
#   + ftputil                          5.1.0  pyhd8ed1ab_0         conda-forge     Cached
#   + connection_pool                  0.0.3  pyhd3deb0d_0         conda-forge     Cached
#   + toposort                          1.10  pyhd8ed1ab_0         conda-forge     Cached
#   + pygments                        2.18.0  pyhd8ed1ab_0         conda-forge     Cached
#   + slacker                         0.14.0  py_0                 conda-forge     Cached
#   + typing_extensions               4.12.2  pyha770c72_0         conda-forge     Cached
#   + tomli                            2.0.1  pyhd8ed1ab_0         conda-forge     Cached
#   + defusedxml                       0.7.1  pyhd8ed1ab_0         conda-forge     Cached
#   + six                             1.16.0  pyh6c4a22f_0         conda-forge     Cached
#   + wcwidth                         0.2.13  pyhd8ed1ab_0         conda-forge     Cached
#   + logmuse                          0.2.6  pyh8c360ce_0         conda-forge     Cached
#   + appdirs                          1.4.4  pyh9f0ad1d_0         conda-forge     Cached
#   + configargparse                     1.7  pyhd8ed1ab_0         conda-forge     Cached
#   + docutils                        0.21.2  pyhd8ed1ab_0         conda-forge     Cached
#   + humanfriendly                     10.0  pyhd8ed1ab_6         conda-forge     Cached
#   + tabulate                         0.9.0  pyhd8ed1ab_1         conda-forge     Cached
#   + reretry                         0.11.8  pyhd8ed1ab_0         conda-forge     Cached
#   + stopit                           1.1.2  py_0                 conda-forge     Cached
#   + throttler                        1.2.2  pyhd8ed1ab_0         conda-forge     Cached
#   + dpath                            2.2.0  pyha770c72_0         conda-forge     Cached
#   + plac                             1.4.3  pyhd8ed1ab_0         conda-forge     Cached
#   + python-fastjsonschema           2.20.0  pyhd8ed1ab_0         conda-forge     Cached
#   + traitlets                       5.14.3  pyhd8ed1ab_0         conda-forge     Cached
#   + mdurl                            0.1.2  pyhd8ed1ab_0         conda-forge     Cached
#   + pkgutil-resolve-name            1.3.10  pyhd8ed1ab_1         conda-forge     Cached
#   + zipp                            3.19.2  pyhd8ed1ab_0         conda-forge     Cached
#   + cachetools                       5.4.0  pyhd8ed1ab_0         conda-forge     Cached
#   + uritemplate                      4.1.1  pyhd8ed1ab_0         conda-forge     Cached
#   + smmap                            5.0.0  pyhd8ed1ab_0         conda-forge     Cached
#   + jmespath                         1.0.1  pyhd8ed1ab_0         conda-forge     Cached
#   + pyasn1                           0.6.0  pyhd8ed1ab_0         conda-forge     Cached
#   + ply                               3.11  pyhd8ed1ab_2         conda-forge     Cached
#   + exceptiongroup                   1.2.2  pyhd8ed1ab_0         conda-forge     Cached
#   + iniconfig                        2.0.0  pyhd8ed1ab_0         conda-forge     Cached
#   + pyparsing                        3.1.2  pyhd8ed1ab_0         conda-forge     Cached
#   + aiosignal                        1.3.1  pyhd8ed1ab_0         conda-forge     Cached
#   + smart_open                       7.0.4  pyhd8ed1ab_0         conda-forge     Cached
#   + jinja2                           3.1.4  pyhd8ed1ab_0         conda-forge     Cached
#   + google-resumable-media           2.7.0  pyhd8ed1ab_0         conda-forge     Cached
#   + perl-extutils-makemaker           7.70  pl5321hd8ed1ab_0     conda-forge     Cached
#   + pyopenssl                       24.2.1  pyhd8ed1ab_2         conda-forge     Cached
#   + proto-plus                      1.23.0  pyhd8ed1ab_0         conda-forge     Cached
#   + googleapis-common-protos        1.63.2  pyhd8ed1ab_0         conda-forge     Cached
#   + coincbc                        2.10.11  0_metapackage        conda-forge     Cached
#   + referencing                     0.35.1  pyhd8ed1ab_0         conda-forge     Cached
#   + typing-extensions               4.12.2  hd8ed1ab_0           conda-forge     Cached
#   + pyu2f                            0.1.5  pyhd8ed1ab_0         conda-forge     Cached
#   + python-dateutil                  2.9.0  pyhd8ed1ab_0         conda-forge     Cached
#   + prettytable                     3.10.2  pyhd8ed1ab_0         conda-forge     Cached
#   + yte                              1.5.4  pyha770c72_0         conda-forge     Cached
#   + markdown-it-py                   3.0.0  pyhd8ed1ab_0         conda-forge     Cached
#   + importlib_resources              6.4.0  pyhd8ed1ab_0         conda-forge     Cached
#   + gitdb                           4.0.11  pyhd8ed1ab_0         conda-forge     Cached
#   + pyasn1-modules                   0.4.0  pyhd8ed1ab_0         conda-forge     Cached
#   + rsa                                4.9  pyhd8ed1ab_0         conda-forge     Cached
#   + stone                            3.3.2  pyhd8ed1ab_0         conda-forge     Cached
#   + pytest                           8.0.2  pyhd8ed1ab_0         conda-forge      252kB
#   + amply                            0.1.6  pyhd8ed1ab_0         conda-forge     Cached
#   + httplib2                        0.22.0  pyhd8ed1ab_0         conda-forge     Cached
#   + async-timeout                    4.0.3  pyhd8ed1ab_0         conda-forge     Cached
#   + setuptools-scm                   8.1.0  pyhd8ed1ab_0         conda-forge     Cached
#   + botocore                      1.34.152  pyge310_1234567_0    conda-forge     Cached
#   + python-irodsclient               2.0.1  pyhd8ed1ab_0         conda-forge     Cached
#   + rich                            13.7.1  pyhd8ed1ab_0         conda-forge     Cached
#   + jsonschema-specifications    2023.12.1  pyhd8ed1ab_0         conda-forge     Cached
#   + gitpython                       3.1.43  pyhd8ed1ab_0         conda-forge     Cached
#   + dropbox                         12.0.2  pyhd8ed1ab_0         conda-forge     Cached
#   + veracitools                      0.1.3  py_0                 conda-forge     Cached
#   + oauth2client                     4.1.3  py_0                 conda-forge     Cached
#   + s3transfer                      0.10.2  pyhd8ed1ab_0         conda-forge     Cached
#   + jsonschema                      4.23.0  pyhd8ed1ab_0         conda-forge     Cached
#   + ubiquerg                         0.8.0  pyhd8ed1ab_0         conda-forge     Cached
#   + boto3                         1.34.152  pyhd8ed1ab_0         conda-forge     Cached
#   + attmap                          0.13.2  pyhd8ed1ab_0         conda-forge     Cached
#   + prodigal                         2.6.3  h031d066_9           bioconda        Cached
#   + pyfastx                          2.1.0  py310h1af8fb7_3      bioconda        Cached
#   + subread                          2.0.6  he4a0461_2           bioconda        Cached
#   + bedtools                        2.31.1  hf5e1c6e_2           bioconda        Cached
#   + hmmer                              3.4  hdbdd923_1           bioconda        Cached
#   + starcode                           1.4  h031d066_5           bioconda        Cached
#   + ncbi-vdb                         3.1.1  h4ac6f70_1           bioconda        Cached
#   + k8                               0.2.5  hdcf5f25_4           bioconda        Cached
#   + strobealign                     0.13.0  h43eeafb_1           bioconda        Cached
#   + dashing                            1.0  h40c17d1_2           bioconda        Cached
#   + htslib                          1.19.1  h81da01d_2           bioconda           3MB
#   + pysam                           0.22.0  py310h41dec4a_1      bioconda           5MB
#   + perl-scalar-list-utils            1.62  pl5321hec16e2b_1     bioconda        Cached
#   + perl-compress-raw-zlib           2.105  pl5321h87f3376_0     bioconda        Cached
#   + perl-compress-raw-bzip2          2.201  pl5321h87f3376_1     bioconda        Cached
#   + perl-list-moreutils-xs           0.430  pl5321h031d066_2     bioconda        Cached
#   + infernal                         1.1.5  pl5321h031d066_2     bioconda        Cached
#   + bwa                             0.7.18  he4a0461_1           bioconda        Cached
#   + entrez-direct                     22.4  he881be0_0           bioconda        Cached
#   + fastani                           1.34  h4dfc31f_2           bioconda        Cached
#   + minimap2                          2.28  he4a0461_1           bioconda        Cached
#   + samtools                        1.19.2  h50ea8bc_1           bioconda         463kB
#   + pybedtools                      0.10.0  py310ha025fb0_2      bioconda        Cached
#   + trnascan-se                     2.0.12  pl5321h031d066_0     bioconda        Cached
#   + coverm                           0.7.0  h07ea13f_1           bioconda        Cached
#   + perl-parent                      0.236  pl5321hdfd78af_2     bioconda        Cached
#   + perl-exporter                     5.72  pl5321hdfd78af_2     bioconda        Cached
#   + perl-common-sense                 3.75  pl5321hdfd78af_0     bioconda        Cached
#   + perl-io-zlib                      1.14  pl5321hdfd78af_0     bioconda        Cached
#   + perl-exporter-tiny            1.002002  pl5321hdfd78af_0     bioconda        Cached
#   + pprodigal                        1.0.1  pyhdfd78af_0         bioconda        Cached
#   + barrnap                            0.9  hdfd78af_4           bioconda        Cached
#   + perl-carp                         1.38  pl5321hdfd78af_4     bioconda        Cached
#   + perl-types-serialiser             1.01  pl5321hdfd78af_0     bioconda        Cached
#   + perl-list-moreutils              0.430  pl5321hdfd78af_0     bioconda        Cached
#   + grpcio                          1.46.3  py310hba10ccf_0      conda-forge        3MB
#   + pynacl                           1.5.0  py310h2372a71_3      conda-forge     Cached
#   + jupyter_core                     5.7.2  py310hff52083_0      conda-forge     Cached
#   + pandas                           2.2.2  py310hf9f9076_1      conda-forge     Cached
#   + pulp                             2.7.0  py310hff52083_1      conda-forge     Cached
#   + aiohttp                          3.9.5  py310h2372a71_0      conda-forge     Cached
#   + perl-encode                       3.19  pl5321hec16e2b_1     bioconda        Cached
#   + perl-pathtools                    3.75  pl5321hec16e2b_3     bioconda        Cached
#   + perl-json-xs                      4.03  pl5321h4ac6f70_3     bioconda        Cached
#   + perl-io-compress                 2.201  pl5321hdbdd923_2     bioconda        Cached
#   + paramiko                         3.4.0  pyhd8ed1ab_0         conda-forge     Cached
#   + nbformat                        5.10.4  pyhd8ed1ab_0         conda-forge     Cached
#   + peppy                           0.40.5  pyhd8ed1ab_0         conda-forge     Cached
#   + google-auth                     2.32.0  pyhff2d567_0         conda-forge     Cached
#   + aioeasywebdav                    2.4.0  pyha770c72_0         conda-forge     Cached
#   + pysftp                           0.2.9  py_1                 conda-forge     Cached
#   + eido                             0.2.2  pyhd8ed1ab_0         conda-forge     Cached
#   + google-api-core                 2.19.1  pyhd8ed1ab_0         conda-forge     Cached
#   + google-auth-httplib2             0.2.0  pyhd8ed1ab_0         conda-forge     Cached
#   + google-cloud-core                2.4.1  pyhd8ed1ab_0         conda-forge     Cached
#   + google-api-python-client       2.138.0  pyhd8ed1ab_0         conda-forge     Cached
#   + google-cloud-storage            2.18.0  pyhff2d567_0         conda-forge     Cached
#   + perl-json                         4.10  pl5321hdfd78af_1     bioconda        Cached
#   + perl-archive-tar                  2.40  pl5321hdfd78af_0     bioconda        Cached
#   + snakemake-minimal               7.32.4  pyhdfd78af_1         bioconda        Cached
#   + snakemake                       7.32.4  hdfd78af_1           bioconda        Cached
#   + blast                           2.15.0  pl5321h6f7f691_1     bioconda         153MB
#   + metapathways               3.5.0.dev54  py_0                 hallamlab       Cached
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates             2023.11.17  hbcca054_0           conda-forge     Cached
#   + ca-certificates               2024.7.4  hbcca054_0           conda-forge     Cached
#   - openssl                          3.2.0  hd590300_1           conda-forge     Cached
#   + openssl                          3.3.1  h4bc722e_2           conda-forge     Cached
#   - certifi                     2023.11.17  pyhd8ed1ab_0         conda-forge     Cached
#   + certifi                       2024.7.4  pyhd8ed1ab_0         conda-forge     Cached
#
#   Summary:
#
#   Install: 193 packages
#   Upgrade: 3 packages
#
#   Total download: 166MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%libgfortran-ng                                      48.4kB @ 658.8kB/s  0.1s
# libgfortran5                                         1.5MB @  16.6MB/s  0.1s
# curl                                                94.9kB @   1.1MB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (3)  ⣾  pytest                                             251.9kB @   2.4MB/s  0.1s
# zlib                                                92.8kB @ 806.2kB/s  0.1s
# grpcio                                               2.7MB @  20.2MB/s  0.0s
# htslib                                               3.0MB @  19.9MB/s  0.1s
# samtools                                           463.4kB @   2.8MB/s  0.0s
# [+] 0.2s
# Downloading  (2)   7%
# Extracting   (6)  ⣾  pysam                                                4.6MB @  18.3MB/s  0.1s
# [+] 0.3s
# Downloading  (1)  13%
# Extracting   (7)  ⣾  [+] 0.4s
# Downloading  (1)  17%
# Extracting   (5)  ⣾  [+] 0.5s
# Downloading  (1)  27%
# Extracting   (4)  ⣾  [+] 0.6s
# Downloading  (1)  40%
# Extracting   (4)  ⣾  [+] 0.7s
# Downloading  (1)  42%
# Extracting   (4)  ⣾  [+] 0.8s
# Downloading  (1)  48%
# Extracting   (4)  ⣾  [+] 0.9s
# Downloading  (1)  55%
# Extracting   (4)  ⣾  [+] 1.0s
# Downloading  (1)  60%
# Extracting   (4)  ⣾  [+] 1.1s
# Downloading  (1)  64%
# Extracting   (4)  ⣾  [+] 1.2s
# Downloading  (1)  65%
# Extracting   (4)  ⣾  [+] 1.3s
# Downloading  (1)  71%
# Extracting   (4)  ⣾  [+] 1.4s
# Downloading  (1)  78%
# Extracting   (4)  ⣾  [+] 1.5s
# Downloading  (1)  81%
# Extracting   (4)  ⣾  [+] 1.6s
# Downloading  (1)  87%
# Extracting   (4)  ⣾  [+] 1.7s
# Downloading  (1)  93%
# Extracting   (4)  ⣾  blast                                              153.1MB @  86.2MB/s  1.7s
# [+] 1.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.6s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
# !mamba init
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.10/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# Added mamba to /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %% [markdown]
# #

# %%
# !metapathways build_db --test
# Out:
# COMMAND   :/usr/local/bin/metapathways build_db --test
# Running test reference DB
# ------------------------------
# mkdir -p /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/temp_cache
#  export XDG_CACHE_HOME=/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/temp_cache
#  snakemake -p -s "/usr/local/lib/python3.10/site-packages/metapathways/build_DBs/Snakefile_test"  -d /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db  --cores 1  --config ref_db_dir="/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db" script_path="/usr/local/lib/python3.10/site-packages/metapathways/build_DBs" aligner="fast" functional_db_names="swissprot_test"  --latency-wait 0 --keep-going --rerun-incomplete  && rm -r /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/temp_cache
# ------------------------------
# /usr/local/lib/python3.10/site-packages/paramiko/pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /usr/local/lib/python3.10/site-packages/paramiko/transport.py:259: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# Building DAG of jobs...
# Using shell: /usr/bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# build_taxmap                   1
# create_dirs_local_files        1
# fetch_ec_db                    1
# make_seq_names_file            3
# make_silva_blast_db            2
# make_swissprot_fast_db         1
# swiss_2_ec                     1
# total                         11
#
# Select jobs to execute...
#
# [Fri Aug  2 22:22:06 2024]
# rule fetch_ec_db:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/starting_build
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat
#     jobid: 4
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat
#     resources: tmpdir=/tmp
#
#
#         wget -O /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat https://ftp.expasy.org/databases/enzyme/enzyme.dat
#         wget -O /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzclass.txt https://ftp.expasy.org/databases/enzyme/enzclass.txt
#         date > /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/Expasy_reldate.txt
#         grep '^Release: ' /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzclass.txt >> /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/Expasy_reldate.txt
#         rm /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzclass.txt
#
# --2024-08-02 22:22:06--  https://ftp.expasy.org/databases/enzyme/enzyme.dat
# Resolving ftp.expasy.org (ftp.expasy.org)... 192.33.215.162
# Connecting to ftp.expasy.org (ftp.expasy.org)|192.33.215.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9390853 (9.0M)
# Saving to: ‘/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat’
#
# /usr/local/lib/pyth 100%[===================>]   8.96M  8.68MB/s    in 1.0s
#
# 2024-08-02 22:22:08 (8.68 MB/s) - ‘/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat’ saved [9390853/9390853]
#
# --2024-08-02 22:22:08--  https://ftp.expasy.org/databases/enzyme/enzclass.txt
# Resolving ftp.expasy.org (ftp.expasy.org)... 192.33.215.162
# Connecting to ftp.expasy.org (ftp.expasy.org)|192.33.215.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20705 (20K) [text/plain]
# Saving to: ‘/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzclass.txt’
#
# /usr/local/lib/pyth 100%[===================>]  20.22K  --.-KB/s    in 0.1s
#
# 2024-08-02 22:22:08 (196 KB/s) - ‘/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzclass.txt’ saved [20705/20705]
#
# [Fri Aug  2 22:22:09 2024]
# Finished job 4.
# 1 of 11 steps (9%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:22:09 2024]
# rule make_swissprot_fast_db:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/swissprot_test
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test.prj
#     jobid: 1
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test.prj
#     resources: tmpdir=/tmp
#
#
#         fastdb -p /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/swissprot_test
#
# [Fri Aug  2 22:22:09 2024]
# Finished job 1.
# 2 of 11 steps (18%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:22:09 2024]
# rule make_silva_blast_db:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_LSU_test
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test.ndb
#     jobid: 7
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test.ndb
#     wildcards: tax_db=SILVA_LSU_test
#     resources: tmpdir=/tmp
#
#
#         makeblastdb -in /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_LSU_test         	-dbtype nucl -parse_seqids -out /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test
#
#
#
# Building a new DB, current time: 08/02/2024 22:22:09
# New DB name:   /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test
# New DB title:  /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_LSU_test
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.000313997 seconds.
#
#
# [Fri Aug  2 22:22:09 2024]
# Finished job 7.
# 3 of 11 steps (27%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:22:09 2024]
# rule make_seq_names_file:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_LSU_test
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test-names.txt
#     jobid: 5
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test-names.txt
#     wildcards: annot_dir=/taxonomic, db_name=SILVA_LSU_test
#     resources: tmpdir=/tmp
#
#
#         grep "^>" /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_LSU_test > /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test-names.txt
#
# [Fri Aug  2 22:22:09 2024]
# Finished job 5.
# 4 of 11 steps (36%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:22:09 2024]
# rule swiss_2_ec:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/swissprot_test, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/EC_map.swissprot_test.tsv
#     jobid: 3
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/EC_map.swissprot_test.tsv; Input files updated by another job: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat
#     resources: tmpdir=/tmp
#
#
#         python /usr/local/lib/python3.10/site-packages/metapathways/build_DBs/swissprot_test_mapper.py /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/enzyme.dat /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories
#
# [Fri Aug  2 22:22:11 2024]
# Finished job 3.
# 5 of 11 steps (45%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:22:11 2024]
# rule create_dirs_local_files:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/starting_build
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/done
#     jobid: 10
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         mkdir -p /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted
#         mkdir -p /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories
#         mkdir -p /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree
#         mkdir -p /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted
#         touch /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/done
#
# [Fri Aug  2 22:22:11 2024]
# Finished job 10.
# 6 of 11 steps (55%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:22:11 2024]
# rule build_taxmap:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/done
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/ncbi_taxonomy_tree.txt
#     jobid: 9
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/ncbi_taxonomy_tree.txt; Input files updated by another job: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         wget -O /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/new_taxdump.tar.gz https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/new_taxdump/new_taxdump.tar.gz
#         tar xvzf /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/new_taxdump.tar.gz -C /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/
#         python /usr/local/lib/python3.10/site-packages/metapathways/build_DBs/taxmap_build.py /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/
#
# --2024-08-02 22:22:11--  https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/new_taxdump/new_taxdump.tar.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.11, 130.14.250.12, 130.14.250.13, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136696119 (130M) [application/x-gzip]
# Saving to: ‘/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/new_taxdump.tar.gz’
#
# /usr/local/lib/pyth 100%[===================>] 130.36M   195MB/s    in 0.7s
#
# 2024-08-02 22:22:12 (195 MB/s) - ‘/usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/new_taxdump.tar.gz’ saved [136696119/136696119]
#
# citations.dmp
# delnodes.dmp
# division.dmp
# excludedfromtype.dmp
# fullnamelineage.dmp
# gencode.dmp
# host.dmp
# images.dmp
# merged.dmp
# names.dmp
# nodes.dmp
# rankedlineage.dmp
# taxidlineage.dmp
# typematerial.dmp
# typeoftype.dmp
#      taxid                       name
# 0        1                       root
# 1   131567         cellular organisms
# 2     2157                    Archaea
# 3  1935183               Asgard group
# 4  2798909  Candidatus Baldrarchaeota
#      taxid              lineage   parent
# 0        1                             1
# 1   131567                             1
# 2     2157               131567   131567
# 3  1935183          131567 2157     2157
# 4  2798909  131567 2157 1935183  1935183
#      taxid                       name              lineage   parent
# 0        1                       root                             1
# 1   131567         cellular organisms                             1
# 2     2157                    Archaea               131567   131567
# 3  1935183               Asgard group          131567 2157     2157
# 4  2798909  Candidatus Baldrarchaeota  131567 2157 1935183  1935183
#                         name    taxid   parent
# 0                       root        1        1
# 1         cellular organisms   131567        1
# 2                    Archaea     2157   131567
# 3               Asgard group  1935183     2157
# 4  Candidatus Baldrarchaeota  2798909  1935183
# [Fri Aug  2 22:23:13 2024]
# Finished job 9.
# 7 of 11 steps (64%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:23:13 2024]
# rule make_seq_names_file:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/swissprot_test
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test-names.txt
#     jobid: 2
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test-names.txt
#     wildcards: annot_dir=/functional, db_name=swissprot_test
#     resources: tmpdir=/tmp
#
#
#         grep "^>" /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/swissprot_test > /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test-names.txt
#
# [Fri Aug  2 22:23:13 2024]
# Finished job 2.
# 8 of 11 steps (73%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:23:13 2024]
# rule make_seq_names_file:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_SSU_test
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test-names.txt
#     jobid: 6
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test-names.txt
#     wildcards: annot_dir=/taxonomic, db_name=SILVA_SSU_test
#     resources: tmpdir=/tmp
#
#
#         grep "^>" /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_SSU_test > /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test-names.txt
#
# [Fri Aug  2 22:23:13 2024]
# Finished job 6.
# 9 of 11 steps (82%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:23:13 2024]
# rule make_silva_blast_db:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_SSU_test
#     output: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test.ndb
#     jobid: 8
#     reason: Missing output files: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test.ndb
#     wildcards: tax_db=SILVA_SSU_test
#     resources: tmpdir=/tmp
#
#
#         makeblastdb -in /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_SSU_test         	-dbtype nucl -parse_seqids -out /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test
#
#
#
# Building a new DB, current time: 08/02/2024 22:23:13
# New DB name:   /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test
# New DB title:  /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/SILVA_SSU_test
# Sequence type: Nucleotide
# Keep MBits: T
# Maximum file size: 3000000000B
# Adding sequences from FASTA; added 1 sequences in 0.000239134 seconds.
#
#
# [Fri Aug  2 22:23:13 2024]
# Finished job 8.
# 10 of 11 steps (91%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:23:13 2024]
# localrule all:
#     input: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test.prj, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test-names.txt, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/EC_map.swissprot_test.tsv, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test-names.txt, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test-names.txt, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test.ndb, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test.ndb, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/ncbi_taxonomy_tree.txt
#     jobid: 0
#     reason: Input files updated by another job: /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test-names.txt, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/ncbi_tree/ncbi_taxonomy_tree.txt, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test-names.txt, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_SSU_test.ndb, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/taxonomic/formatted/SILVA_LSU_test.ndb, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test-names.txt, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional/formatted/swissprot_test.prj, /usr/local/lib/python3.10/site-packages/metapathways/regtests/test_db/functional_categories/EC_map.swissprot_test.tsv
#     resources: tmpdir=/tmp
#
# [Fri Aug  2 22:23:13 2024]
# Finished job 0.
# 11 of 11 steps (100%) done
# Complete log: .snakemake/log/2024-08-02T222205.735843.snakemake.log

# %%
# !metapathways run --test
# Out:
# COMMAND   :/usr/local/bin/metapathways run --test
# output dir /content/test
# RUNNING MetaPathways: v3.5.0.dev54
# ==============  RUNNING STEPS IN BLOCK 0 ================
#
# ######################################################################################################
#
# PROCESSING INPUT /usr/local/lib/python3.10/site-packages/metapathways/regtests/input/k12_test.fasta.gz [STEPS BLOCK 0]
# PREPROCESSING THE INPUT                                     ..... Success!
# ORF PREDICTION                                              ..... Success!
# CREATING AMINO ACID SEQS FROM GFF FILE                      ..... Success!
# FILTER AMINO ACID SEQS                                      ..... Success!
#
# ######################################################################################################
#
# PROCESSING INPUT /usr/local/lib/python3.10/site-packages/metapathways/regtests/input/k12_test.fasta.gz [STEPS BLOCK 1]
# FASTING AMINO SEQS AGAINST swissprot_test                   ..... Success!
#
# ######################################################################################################
#
# PROCESSING INPUT /usr/local/lib/python3.10/site-packages/metapathways/regtests/input/k12_test.fasta.gz [STEPS BLOCK 2]
# COMPUTING REFSCORES FOR BITSCORE                            ..... Success!
# PARSING FAST OUTPUT FOR swissprot_test                      ..... Success!
# SCANNING FOR rRNA USING BARRNAP                             ..... Success!
# ANNOTATING rRNA USING DB SILVA_SSU_test                     ..... Success!
# ANNOTATING rRNA USING DB SILVA_LSU_test                     ..... Success!
# SCANNING FOR tRNA USING tRNA-Scan SE                        ..... Success!
# ANNOTATE ORFS
# 	INFO:	Processing database : swissprot_test
#
# 	INFO:	Number of annotations in DB  swissprot_test: 39..... Success!
# CREATING REPORT FILE FOR ORF ANNOTATION
# 	INFO:	Memory used  = 1.371556 MB
#
# 	INFO:	Processing database : swissprot_test...done
#
# 	INFO:	Number of collected hits in swissprot_test: 39
# 	INFO:	Number of ORFs processed  : 72
#
# 	INFO:	number of hits in swissprot_test: 39..... Success!
# GENBANK FILE                                                ..... Success!
# PATHOLOGIC INPUT                                            ..... Success!
# RUNNING TPM_CALCULATION                                     ..... Success!
#             ***********
# INFO : FINISHED PROCESSING THE SAMPLES
#              THE END
#             ***********

# %% [markdown]
# # Testing the MetaPathways installation

# %%
# !rm -r mp_dbs
# !mkdir -p mp_dbs/functional
# !metapathways build_db -d mp_dbs --func swissprot -a fast
# Out:
# COMMAND   :/usr/local/bin/metapathways build_db -d mp_dbs --func swissprot -a fast
# ------------------------------
# mkdir -p /content/mp_dbs/temp_cache
#  export XDG_CACHE_HOME=/content/mp_dbs/temp_cache
#  snakemake -p -s "/usr/local/lib/python3.10/site-packages/metapathways/build_DBs/Snakefile"  -d /content/mp_dbs  --cores 1  --config ref_db_dir="/content/mp_dbs" script_path="/usr/local/lib/python3.10/site-packages/metapathways/build_DBs" aligner="fast" functional_db_names="swissprot"  --latency-wait 0 --keep-going --rerun-incomplete  && rm -r /content/mp_dbs/temp_cache
# ------------------------------
# /usr/local/lib/python3.10/site-packages/paramiko/pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /usr/local/lib/python3.10/site-packages/paramiko/transport.py:259: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# Building DAG of jobs...
# Using shell: /usr/bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# build_taxmap                   1
# create_dirs_local_files        1
# fetch_ec_db                    1
# fetch_silva_db                 1
# fetch_swissprot_db             1
# make_seq_names_file            3
# make_silva_blast_db            1
# make_swissprot_fast_db         1
# swiss_2_ec                     1
# total                         12
#
# Select jobs to execute...
#
# [Fri Aug  2 23:39:07 2024]
# rule fetch_swissprot_db:
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/functional/swissprot
#     jobid: 2
#     reason: Missing output files: /content/mp_dbs/functional/swissprot
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/functional/swissprot.gz https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
#         gunzip /content/mp_dbs/functional/swissprot.gz
#         wget -O /content/mp_dbs/functional_categories/swissprot_reldate.txt https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/reldate.txt
#         date > /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         cat /content/mp_dbs/functional_categories/swissprot_reldate.txt >> /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         rm /content/mp_dbs/functional_categories/swissprot_reldate.txt
#
# --2024-08-02 23:39:07--  https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
# Resolving ftp.uniprot.org (ftp.uniprot.org)... 128.175.240.195
# Connecting to ftp.uniprot.org (ftp.uniprot.org)|128.175.240.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92500409 (88M) [application/x-gzip]
# Saving to: ‘/content/mp_dbs/functional/swissprot.gz’
#
# /content/mp_dbs/fun 100%[===================>]  88.21M   187MB/s    in 0.5s
#
# 2024-08-02 23:39:08 (187 MB/s) - ‘/content/mp_dbs/functional/swissprot.gz’ saved [92500409/92500409]
#
# /content/mp_dbs/functional_categories/swissprot_reldate.txt: No such file or directory
# [Fri Aug  2 23:39:11 2024]
# Error in rule fetch_swissprot_db:
#     jobid: 2
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/functional/swissprot
#     shell:
#
#         wget -O /content/mp_dbs/functional/swissprot.gz https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
#         gunzip /content/mp_dbs/functional/swissprot.gz
#         wget -O /content/mp_dbs/functional_categories/swissprot_reldate.txt https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/reldate.txt
#         date > /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         cat /content/mp_dbs/functional_categories/swissprot_reldate.txt >> /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         rm /content/mp_dbs/functional_categories/swissprot_reldate.txt
#
#         (one of the commands exited with non-zero exit code; note that snakemake uses bash strict mode!)
#
# Removing output files of failed job fetch_swissprot_db since they might be corrupted:
# /content/mp_dbs/functional/swissprot
# Select jobs to execute...
#
# [Fri Aug  2 23:39:11 2024]
# rule fetch_ec_db:
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/functional_categories/enzyme.dat
#     jobid: 5
#     reason: Missing output files: /content/mp_dbs/functional_categories/enzyme.dat
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/functional_categories/enzyme.dat https://ftp.expasy.org/databases/enzyme/enzyme.dat
#         wget -O /content/mp_dbs/functional_categories/enzclass.txt https://ftp.expasy.org/databases/enzyme/enzclass.txt
#         date > /content/mp_dbs/functional_categories/Expasy_reldate.txt
#         grep '^Release: ' /content/mp_dbs/functional_categories/enzclass.txt >> /content/mp_dbs/functional_categories/Expasy_reldate.txt
#         rm /content/mp_dbs/functional_categories/enzclass.txt
#
# --2024-08-02 23:39:11--  https://ftp.expasy.org/databases/enzyme/enzyme.dat
# Resolving ftp.expasy.org (ftp.expasy.org)... 192.33.215.162
# Connecting to ftp.expasy.org (ftp.expasy.org)|192.33.215.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9390853 (9.0M)
# Saving to: ‘/content/mp_dbs/functional_categories/enzyme.dat’
#
# /content/mp_dbs/fun 100%[===================>]   8.96M  8.65MB/s    in 1.0s
#
# 2024-08-02 23:39:13 (8.65 MB/s) - ‘/content/mp_dbs/functional_categories/enzyme.dat’ saved [9390853/9390853]
#
# --2024-08-02 23:39:13--  https://ftp.expasy.org/databases/enzyme/enzclass.txt
# Resolving ftp.expasy.org (ftp.expasy.org)... 192.33.215.162
# Connecting to ftp.expasy.org (ftp.expasy.org)|192.33.215.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20705 (20K) [text/plain]
# Saving to: ‘/content/mp_dbs/functional_categories/enzclass.txt’
#
# /content/mp_dbs/fun 100%[===================>]  20.22K  --.-KB/s    in 0.1s
#
# 2024-08-02 23:39:13 (195 KB/s) - ‘/content/mp_dbs/functional_categories/enzclass.txt’ saved [20705/20705]
#
# [Fri Aug  2 23:39:14 2024]
# Finished job 5.
# 1 of 12 steps (8%) done
# Select jobs to execute...
#
# [Fri Aug  2 23:39:14 2024]
# rule create_dirs_local_files:
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/taxonomic/formatted/done
#     jobid: 8
#     reason: Missing output files: /content/mp_dbs/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         mkdir -p /content/mp_dbs/functional/formatted
#         mkdir -p /content/mp_dbs/functional_categories
#         mkdir -p /content/mp_dbs/ncbi_tree
#         mkdir -p /content/mp_dbs/taxonomic/formatted
#         touch /content/mp_dbs/taxonomic/formatted/done
#
# [Fri Aug  2 23:39:14 2024]
# Finished job 8.
# 2 of 12 steps (17%) done
# Select jobs to execute...
#
# [Fri Aug  2 23:39:14 2024]
# rule fetch_silva_db:
#     input: /content/mp_dbs/taxonomic/formatted/done
#     output: /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc, /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc
#     jobid: 7
#     reason: Missing output files: /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc, /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc; Input files updated by another job: /content/mp_dbs/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_SSURef_NR99_tax_silva_trunc.fasta.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz
#         date > /content/mp_dbs/functional_categories/SILVA_reldate.txt
#         echo "Release: " 138.1 >> /content/mp_dbs/functional_categories/SILVA_reldate.txt
#
# --2024-08-02 23:39:14--  https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz
# Resolving www.arb-silva.de (www.arb-silva.de)... 194.94.219.5
# Connecting to www.arb-silva.de (www.arb-silva.de)|194.94.219.5|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-08-02 23:39:14 ERROR 404: Not Found.
#
# [Fri Aug  2 23:39:14 2024]
# Error in rule fetch_silva_db:
#     jobid: 7
#     input: /content/mp_dbs/taxonomic/formatted/done
#     output: /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc, /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc
#     shell:
#
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_SSURef_NR99_tax_silva_trunc.fasta.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz
#         date > /content/mp_dbs/functional_categories/SILVA_reldate.txt
#         echo "Release: " 138.1 >> /content/mp_dbs/functional_categories/SILVA_reldate.txt
#
#         (one of the commands exited with non-zero exit code; note that snakemake uses bash strict mode!)
#
# Select jobs to execute...
#
# [Fri Aug  2 23:39:14 2024]
# rule build_taxmap:
#     input: /content/mp_dbs/taxonomic/formatted/done
#     output: /content/mp_dbs/ncbi_tree/ncbi_taxonomy_tree.txt
#     jobid: 11
#     reason: Missing output files: /content/mp_dbs/ncbi_tree/ncbi_taxonomy_tree.txt; Input files updated by another job: /content/mp_dbs/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/ncbi_tree/new_taxdump.tar.gz https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/new_taxdump/new_taxdump.tar.gz
#         tar xvzf /content/mp_dbs/ncbi_tree/new_taxdump.tar.gz -C /content/mp_dbs/ncbi_tree/
#         python /usr/local/lib/python3.10/site-packages/metapathways/build_DBs/taxmap_build.py /content/mp_dbs/ncbi_tree/
#
# --2024-08-02 23:39:14--  https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/new_taxdump/new_taxdump.tar.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.31, 130.14.250.7, 130.14.250.10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136692442 (130M) [application/x-gzip]
# Saving to: ‘/content/mp_dbs/ncbi_tree/new_taxdump.tar.gz’
#
# /content/mp_dbs/ncb 100%[===================>] 130.36M   146MB/s    in 0.9s
#
# 2024-08-02 23:39:15 (146 MB/s) - ‘/content/mp_dbs/ncbi_tree/new_taxdump.tar.gz’ saved [136692442/136692442]
#
# citations.dmp
# delnodes.dmp
# division.dmp
# excludedfromtype.dmp
# fullnamelineage.dmp
# gencode.dmp
# host.dmp
# images.dmp
# merged.dmp
# names.dmp
# nodes.dmp
# rankedlineage.dmp
# taxidlineage.dmp
# typematerial.dmp
# typeoftype.dmp
#      taxid                       name
# 0        1                       root
# 1   131567         cellular organisms
# 2     2157                    Archaea
# 3  1935183               Asgard group
# 4  2798909  Candidatus Baldrarchaeota
#      taxid              lineage   parent
# 0        1                             1
# 1   131567                             1
# 2     2157               131567   131567
# 3  1935183          131567 2157     2157
# 4  2798909  131567 2157 1935183  1935183
#      taxid                       name              lineage   parent
# 0        1                       root                             1
# 1   131567         cellular organisms                             1
# 2     2157                    Archaea               131567   131567
# 3  1935183               Asgard group          131567 2157     2157
# 4  2798909  Candidatus Baldrarchaeota  131567 2157 1935183  1935183
#                         name    taxid   parent
# 0                       root        1        1
# 1         cellular organisms   131567        1
# 2                    Archaea     2157   131567
# 3               Asgard group  1935183     2157
# 4  Candidatus Baldrarchaeota  2798909  1935183
# [Fri Aug  2 23:40:25 2024]
# Finished job 11.
# 3 of 12 steps (25%) done
# Exiting because a job execution failed. Look above for error message
# Complete log: .snakemake/log/2024-08-02T233907.162019.snakemake.log

# %%
# !cat mp_dbs/.snakemake/log/2024-08-02T222938.274271.snakemake.log
# Out:
# Building DAG of jobs...
# Using shell: /usr/bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job                        count
# -----------------------  -------
# all                            1
# build_taxmap                   1
# create_dirs_local_files        1
# fetch_ec_db                    1
# fetch_silva_db                 1
# fetch_swissprot_db             1
# make_seq_names_file            3
# make_silva_blast_db            1
# make_swissprot_fast_db         1
# swiss_2_ec                     1
# total                         12
#
# Select jobs to execute...
#
# [Fri Aug  2 22:29:38 2024]
# rule fetch_swissprot_db:
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/functional/swissprot
#     jobid: 2
#     reason: Missing output files: /content/mp_dbs/functional/swissprot
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/functional/swissprot.gz https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
#         gunzip /content/mp_dbs/functional/swissprot.gz
#         wget -O /content/mp_dbs/functional_categories/swissprot_reldate.txt https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/reldate.txt
#         date > /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         cat /content/mp_dbs/functional_categories/swissprot_reldate.txt >> /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         rm /content/mp_dbs/functional_categories/swissprot_reldate.txt
#
# [Fri Aug  2 22:29:43 2024]
# Error in rule fetch_swissprot_db:
#     jobid: 2
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/functional/swissprot
#     shell:
#
#         wget -O /content/mp_dbs/functional/swissprot.gz https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
#         gunzip /content/mp_dbs/functional/swissprot.gz
#         wget -O /content/mp_dbs/functional_categories/swissprot_reldate.txt https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/reldate.txt
#         date > /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         cat /content/mp_dbs/functional_categories/swissprot_reldate.txt >> /content/mp_dbs/functional_categories/SwissProt_reldate.txt
#         rm /content/mp_dbs/functional_categories/swissprot_reldate.txt
#
#         (one of the commands exited with non-zero exit code; note that snakemake uses bash strict mode!)
#
# Removing output files of failed job fetch_swissprot_db since they might be corrupted:
# /content/mp_dbs/functional/swissprot
# Select jobs to execute...
#
# [Fri Aug  2 22:29:43 2024]
# rule fetch_ec_db:
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/functional_categories/enzyme.dat
#     jobid: 5
#     reason: Missing output files: /content/mp_dbs/functional_categories/enzyme.dat
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/functional_categories/enzyme.dat https://ftp.expasy.org/databases/enzyme/enzyme.dat
#         wget -O /content/mp_dbs/functional_categories/enzclass.txt https://ftp.expasy.org/databases/enzyme/enzclass.txt
#         date > /content/mp_dbs/functional_categories/Expasy_reldate.txt
#         grep '^Release: ' /content/mp_dbs/functional_categories/enzclass.txt >> /content/mp_dbs/functional_categories/Expasy_reldate.txt
#         rm /content/mp_dbs/functional_categories/enzclass.txt
#
# [Fri Aug  2 22:29:45 2024]
# Finished job 5.
# 1 of 12 steps (8%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:29:45 2024]
# rule create_dirs_local_files:
#     input: /content/mp_dbs/starting_build
#     output: /content/mp_dbs/taxonomic/formatted/done
#     jobid: 8
#     reason: Missing output files: /content/mp_dbs/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         mkdir -p /content/mp_dbs/functional/formatted
#         mkdir -p /content/mp_dbs/functional_categories
#         mkdir -p /content/mp_dbs/ncbi_tree
#         mkdir -p /content/mp_dbs/taxonomic/formatted
#         touch /content/mp_dbs/taxonomic/formatted/done
#
# [Fri Aug  2 22:29:45 2024]
# Finished job 8.
# 2 of 12 steps (17%) done
# Select jobs to execute...
#
# [Fri Aug  2 22:29:45 2024]
# rule fetch_silva_db:
#     input: /content/mp_dbs/taxonomic/formatted/done
#     output: /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc, /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc
#     jobid: 7
#     reason: Missing output files: /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc, /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc; Input files updated by another job: /content/mp_dbs/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_SSURef_NR99_tax_silva_trunc.fasta.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz
#         date > /content/mp_dbs/functional_categories/SILVA_reldate.txt
#         echo "Release: " 138.1 >> /content/mp_dbs/functional_categories/SILVA_reldate.txt
#
# [Fri Aug  2 22:29:46 2024]
# Error in rule fetch_silva_db:
#     jobid: 7
#     input: /content/mp_dbs/taxonomic/formatted/done
#     output: /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc, /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc
#     shell:
#
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz
#         wget -O /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/SILVA_138.1_SSURef_NR99_tax_silva_trunc.fasta.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz
#         gunzip /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz
#         date > /content/mp_dbs/functional_categories/SILVA_reldate.txt
#         echo "Release: " 138.1 >> /content/mp_dbs/functional_categories/SILVA_reldate.txt
#
#         (one of the commands exited with non-zero exit code; note that snakemake uses bash strict mode!)
#
# Select jobs to execute...
#
# [Fri Aug  2 22:29:46 2024]
# rule build_taxmap:
#     input: /content/mp_dbs/taxonomic/formatted/done
#     output: /content/mp_dbs/ncbi_tree/ncbi_taxonomy_tree.txt
#     jobid: 11
#     reason: Missing output files: /content/mp_dbs/ncbi_tree/ncbi_taxonomy_tree.txt; Input files updated by another job: /content/mp_dbs/taxonomic/formatted/done
#     resources: tmpdir=/tmp
#
#
#         wget -O /content/mp_dbs/ncbi_tree/new_taxdump.tar.gz https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/new_taxdump/new_taxdump.tar.gz
#         tar xvzf /content/mp_dbs/ncbi_tree/new_taxdump.tar.gz -C /content/mp_dbs/ncbi_tree/
#         python /usr/local/lib/python3.10/site-packages/metapathways/build_DBs/taxmap_build.py /content/mp_dbs/ncbi_tree/
#
# [Fri Aug  2 22:30:48 2024]
# Finished job 11.
# 3 of 12 steps (25%) done
# Exiting because a job execution failed. Look above for error message
# Complete log: .snakemake/log/2024-08-02T222938.274271.snakemake.log

# %%
# !wget -O /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/release_138.1/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz
# !wget -O /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz https://www.arb-silva.de/fileadmin/silva_databases/release_138.1/Exports/SILVA_138.1_SSURef_NR99_tax_silva_trunc.fasta.gz
# !gunzip /content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz
# !gunzip /content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz
# !date > /content/mp_dbs/functional_categories/SILVA_reldate.txt
# !echo "Release: " 138.1 >> /content/mp_dbs/functional_categories/SILVA_reldate.txt
# Out:
# --2024-08-02 23:35:21--  https://www.arb-silva.de/fileadmin/silva_databases/release_138.1/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz
# Resolving www.arb-silva.de (www.arb-silva.de)... 194.94.219.5
# Connecting to www.arb-silva.de (www.arb-silva.de)|194.94.219.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66548042 (63M) [application/gzip]
# Saving to: ‘/content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz’
#
# /content/mp_dbs/tax 100%[===================>]  63.46M  24.7MB/s    in 2.6s
#
# 2024-08-02 23:35:24 (24.7 MB/s) - ‘/content/mp_dbs/taxonomic/SILVA_138.1_LSURef_NR99_tax_silva_trunc.gz’ saved [66548042/66548042]
#
# --2024-08-02 23:35:25--  https://www.arb-silva.de/fileadmin/silva_databases/release_138.1/Exports/SILVA_138.1_SSURef_NR99_tax_silva_trunc.fasta.gz
# Resolving www.arb-silva.de (www.arb-silva.de)... 194.94.219.5
# Connecting to www.arb-silva.de (www.arb-silva.de)|194.94.219.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 195410064 (186M) [application/gzip]
# Saving to: ‘/content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz’
#
# /content/mp_dbs/tax 100%[===================>] 186.36M  33.7MB/s    in 6.1s
#
# 2024-08-02 23:35:31 (30.5 MB/s) - ‘/content/mp_dbs/taxonomic/SILVA_138.1_SSURef_NR99_tax_silva_trunc.gz’ saved [195410064/195410064]

# %% [markdown]
# The Silva link no longer works because it was for the *current* version, which has been incremented. We need to use the following link for archived versions:
# https://www.arb-silva.de/fileadmin/silva_databases/release_138.1/Exports/SILVA_138.1_LSURef_NR99_tax_silva_trunc.fasta.gz

# %%
# !ls -lh mp_dbs
# Out:
# total 16K
# drwxr-xr-x 2 root root 4.0K Aug  2 23:28 functional_categories
# drwxr-xr-x 2 root root 4.0K Aug  2 23:16 ncbi_tree
# -rw-r--r-- 1 root root    0 Aug  2 23:15 starting_build
# drwxr-xr-x 3 root root 4.0K Aug  2 23:35 taxonomic
# drwxr-xr-x 3 root root 4.0K Aug  2 23:15 temp_cache

# %% [markdown]
# It seems that the problem with SwissProt is that the install scripts are not ensuring that the 'functional' directory was created before attempting to install SwissProt there. Actually it's weird, because some stuff is being downloaded to `functional`, and others are being downloaded to `functional_categories`.
